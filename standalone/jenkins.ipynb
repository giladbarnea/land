# %%
from api4jenkins import Jenkins as J
import os
from subprocess import getoutput
import sys
import time

# %%
j = J("http://j*****r-s**u-01.r***b.l***l/", auth=("c*-g****-h****o", "********4"))

# %%
job = j.get_job("allot_sec***_t**m_mul******ct")

# %%
while True:
    time.sleep(10)
    pr = job.get("PR-5323")
    if not pr:
        print("PR-5323 is None")
        continue
    lastbuild = pr.get_last_build()
    print("{0.building}" % lastbuild)
# Out:
# 'PR-5323 is None': str
# └─'PR-5323 is None'
# 'PR-5323 is None': str
# └─'PR-5323 is None'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.ipython/profile_default/startup/startup.py in <module>
#       1 while True:
# ----> 2     time.sleep(10)
#       3     pr = job.get('PR-5323')
#       4     if not pr:
#       5         print('PR-5323 is None')
#
# KeyboardInterrupt:
